# %%
import cv2
cv2.__version__
# Out:
# '4.7.0'

# %%
image = cv2.imread('lena.png', 0)

# 1 Imread_Color
# 0 Imread_Grayscale
# -1 Imread_Unchanged
# Out:
# [ WARN:0@1291.314] global loadsave.cpp:244 findDecoder imread_('lena.png'): can't open/read file: check file path/integrity

# %%
print ( image )

if image == None: 
    print ( "something went wrong! " )
# Out:
# None
# something went wrong!

# %%
#pointing to Image Folder
import os
root = os.path.join(os.getcwd(), '..', 'Images')
# root is the address of Image Folder

# %%
# image = cv2.imread( path, -1/0/1 )

lena = cv2.imread(os.path.join(root, 'lena.png'), 0)

old_lena_original = cv2.imread(os.path.join(root, 'lena_now.png'), -1)
old_lena_grayscale = cv2.imread(os.path.join(root, 'lena_now.png'), 0)
old_lena_color = cv2.imread(os.path.join(root, 'lena_now.png'), 1)

# %%
print(old_lena_original)
# Out:
# [[[ 56  73  96]
#   [ 50  68  90]
#   [ 50  68  90]
#   ...
#   [ 57  76 101]
#   [ 58  78 102]
#   [ 58  78 102]]
#
#  [[ 56  73  96]
#   [ 50  68  90]
#   [ 50  68  90]
#   ...
#   [ 57  76 101]
#   [ 58  78 102]
#   [ 58  78 102]]
#
#  [[ 57  75  97]
#   [ 50  68  90]
#   [ 50  68  90]
#   ...
#   [ 57  76 101]
#   [ 58  78 102]
#   [ 58  78 102]]
#
#  ...
#
#  [[ 25  39  46]
#   [ 14  27  34]
#   [ 13  26  33]
#   ...
#   [ 55  75  97]
#   [ 55  75  97]
#   [ 55  75  97]]
#
#  [[ 25  39  46]
#   [ 15  29  36]
#   [ 15  29  36]
#   ...
#   [ 54  74  96]
#   [ 54  74  96]
#   [ 54  74  96]]
#
#  [[ 25  39  46]
#   [ 16  30  37]
#   [ 15  29  36]
#   ...
#   [ 54  74  96]
#   [ 54  74  96]
#   [ 54  74  96]]]

# %%
os.path.join(root, 'lena.png')
# Out:
# '/mnt/c/Users/user/desktop/Image Processing/Image-Processing/OpenCV Basics/../Images/lena.png'

# %%
os.path.join(root, 'lena_now.png')
# Out:
# '/mnt/c/Users/user/desktop/Image Processing/Image-Processing/OpenCV Basics/../Images/lena_now.png'

# %%
# %matplotlib inline
# inline show
from matplotlib import pyplot as plt

# %%
plt.imshow(cv2.cvtColor(old_lena_original, cv2.COLOR_BGR2RGB))
plt.show()
